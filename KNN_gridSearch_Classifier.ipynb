# %%
#KNN is a Classificaiton , Nearst Neighbour. K value.
#Grid Search 
import pandas as pd  
import numpy as np 
import matplotlib.pyplot as plt
dataset=pd.read_csv("CKD.csv") # correct dataset
print("dataset available")
df = pd.DataFrame(dataset)
num_rows = len(df.index)
num_columns = len(df.columns)
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# dataset available
# Number of rows: 399
# Number of columns: 25

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hrmo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset=dataset.replace({True:1,False:0})
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6168\621106914.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset=dataset.replace({True:1,False:0})

# %%
independent=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
dependent=dataset[['classification_yes']]

# %%
#dataset

# %%
from sklearn.model_selection import train_test_split
x_train5,x_test5,y_train5,y_test5 = train_test_split(independent,dependent, test_size=0.3,random_state=0)

# %%
x_train5.shape,x_test5.shape,y_train5.shape,y_test5.shape
# Out:
# ((279, 27), (120, 27), (279, 1), (120, 1))

# %%
dataset["classification_yes"].value_counts()
# Out:
# classification_yes
# 1    249
# 0    150
# Name: count, dtype: int64

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier()  # Define the KNN Model
param_grid = {
    'n_neighbors': range(1, 31),  # Test k from 1 to 30
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

grid_search = GridSearchCV(knn, param_grid, cv=5, scoring='accuracy')

grid_search.fit(x_train5,y_train5)
print("Model Created")

import warnings
warnings.filterwarnings('ignore')
# Out:
# Model Created

# %%
print("Best parameters found: ", grid_search.best_params_)
print("Best cross-validation score: ", grid_search.best_score_)
# Out:
# Best parameters found:  {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'uniform'}
# Best cross-validation score:  0.7707792207792209

# %%
result = grid_search.cv_results_
grid_predictions =  grid_search.predict(x_test5)
from sklearn.metrics import confusion_matrix 
cm = confusion_matrix(y_test5,grid_predictions) 
print("The result for KNN CVis:'\n'", cm)
# Out:
# The result for KNN CVis:'
# ' [[41  4]
#  [18 57]]

# %%
#result
table = pd.DataFrame.from_dict(result)
table
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.006755      0.003774         0.022826        0.010863
# 1         0.003444      0.000931         0.006899        0.001161
# 2         0.002655      0.000106         0.009361        0.000337
# 3         0.003243      0.001325         0.006324        0.000739
# 4         0.002895      0.000431         0.009341        0.000377
# ..             ...           ...              ...             ...
# 115       0.004061      0.001439         0.008655        0.001725
# 116       0.002893      0.000332         0.010931        0.000453
# 117       0.002906      0.000369         0.007688        0.001326
# 118       0.003514      0.001193         0.010488        0.001030
# 119       0.003366      0.001170         0.007635        0.001240
#
#     param_metric  param_n_neighbors param_weights  \
# 0      euclidean                  1       uniform
# 1      euclidean                  1      distance
# 2      euclidean                  2       uniform
# 3      euclidean                  2      distance
# 4      euclidean                  3       uniform
# ..           ...                ...           ...
# 115    manhattan                 28      distance
# 116    manhattan                 29       uniform
# 117    manhattan                 29      distance
# 118    manhattan                 30       uniform
# 119    manhattan                 30      distance
#
#                                                 params  split0_test_score  \
# 0    {'metric': 'euclidean', 'n_neighbors': 1, 'wei...           0.625000
# 1    {'metric': 'euclidean', 'n_neighbors': 1, 'wei...           0.625000
# 2    {'metric': 'euclidean', 'n_neighbors': 2, 'wei...           0.660714
# 3    {'metric': 'euclidean', 'n_neighbors': 2, 'wei...           0.625000
# 4    {'metric': 'euclidean', 'n_neighbors': 3, 'wei...           0.571429
# ..                                                 ...                ...
# 115  {'metric': 'manhattan', 'n_neighbors': 28, 'we...           0.714286
# 116  {'metric': 'manhattan', 'n_neighbors': 29, 'we...           0.785714
# 117  {'metric': 'manhattan', 'n_neighbors': 29, 'we...           0.714286
# 118  {'metric': 'manhattan', 'n_neighbors': 30, 'we...           0.785714
# 119  {'metric': 'manhattan', 'n_neighbors': 30, 'we...           0.750000
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0             0.750000           0.750000           0.803571
# 1             0.750000           0.750000           0.803571
# 2             0.732143           0.696429           0.732143
# 3             0.750000           0.750000           0.803571
# 4             0.678571           0.696429           0.732143
# ..                 ...                ...                ...
# 115           0.750000           0.750000           0.785714
# 116           0.714286           0.732143           0.767857
# 117           0.750000           0.767857           0.785714
# 118           0.714286           0.714286           0.732143
# 119           0.732143           0.767857           0.767857
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.818182         0.749351        0.068032               16
# 1             0.818182         0.749351        0.068032               16
# 2             0.818182         0.727922        0.052328               62
# 3             0.818182         0.749351        0.068032               16
# 4             0.763636         0.688442        0.065448              118
# ..                 ...              ...             ...              ...
# 115           0.690909         0.738182        0.032694               43
# 116           0.654545         0.730909        0.045778               61
# 117           0.690909         0.741753        0.034703               35
# 118           0.672727         0.723831        0.036585               78
# 119           0.690909         0.741753        0.028665               35
#
# [120 rows x 16 columns]

# %%
from sklearn.metrics import classification_report
clf_report = classification_report(y_test5,grid_predictions)

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.91      0.79        45
#            1       0.93      0.76      0.84        75
#
#     accuracy                           0.82       120
#    macro avg       0.81      0.84      0.81       120
# weighted avg       0.84      0.82      0.82       120

# %%
#classifier
grid_search
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'metric': ['euclidean', 'manhattan'],
#                          'n_neighbors': range(1, 31),
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy')

# %%
#F1 SCORE
from sklearn.metrics import f1_score
f1_macro =  f1_score(y_test5,grid_predictions,average='weighted')
print("The f1 score vaule for best parameter {} is:'\n'".format(grid_search.best_params_),f1_macro)
# Out:
# The f1 score vaule for best parameter {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'uniform'} is:'
# ' 0.8195701357466063

# %%
#roc_auc Area Under Curve  1 is the best 
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test5,grid_search.predict_proba(x_test5)[:,1])
# Out:
# np.float64(0.8355555555555556)

# %%
age_input=float(input("age"))
bp_input=float(input("bp"))
al_input=float(input("al"))
su_input=float(input("su"))
bgr_input=float(input("bgr"))
bu_input=float(input("bu"))
sc_input=float(input("sc"))
sod_input=float(input("sod"))
pot_input=float(input("pot"))
hrmo_input=float(input("hrmo"))
pcv_input=float(input("pcv"))
wc_input=float(input("wc"))
rc_input=float(input("rc"))
sg_b_input=float(input("sg_b"))
sg_c_input=float(input("sg_c"))
sg_d_input=float(input("sg_d"))
sg_e_input=float(input("sg_e"))
rbc_input=float(input("rbc_normal"))
pc_input=float(input("pc_normal"))
pcc_input=float(input("pcc_present"))
ba_input=float(input("ba_present"))
htn_input=float(input("htn_yes"))
dm_input=float(input("dm_yes"))
cad_input=float(input("cad_yes"))
appet_input=float(input("appet_yes"))
pe_input=float(input("pe_yes"))
ane_input=float(input("ane_yes"))
# Out:
# age 43
# bp 110
# al 0
# su 0
# bgr 100
# bu 26
# sc 0.6
# sod 137
# pot 4.4
# hrmo 15.8
# pcv 49
# wc 6500
# rc 5.4
# sg_b 1
# sg_c 0
# sg_d 0
# sg_e 0
# rbc_normal 1
# pc_normal 1
# pcc_present 1
# ba_present 1
# htn_yes 1
# dm_yes 1
# cad_yes 1
# appet_yes 1
# pe_yes 1
# ane_yes 0

# %%
Future_Prediction=grid_search.predict([[age_input,bp_input,al_input,su_input,bgr_input,bu_input,sc_input,sod_input,pot_input,hrmo_input,pcv_input,wc_input,
                                 rc_input,sg_b_input,sg_c_input,sg_d_input,sg_e_input,rbc_input,pc_input,pcc_input,ba_input,htn_input,dm_input,
                                 cad_input,appet_input,pe_input,ane_input]])
print("Future_Prediction={}".format(Future_Prediction))
print("The possibility of Kidney Disease is:",Future_Prediction)
# Out:
# Future_Prediction=[0]
# The possibility of Kidney Disease is: [0]
